# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
class Web_Scraping:
    
    def Beautiful_Soup(self):
        # Fetch the webpage and store in a response.
        response = requests.get("https://dot.ca.gov/programs/procurement-and-contracts/contracts-out-for-bid")
        html_data = response.text
        # Parse the page using BeautifulSoup
        data = BeautifulSoup(html_data,"html.parser")

        # create list of all columns and put extra column name link.
        column_name = []
        a = data.find_all("th")
        for i in a:
            column_name.append(i.get_text())
        column_name.append("link")

        # create list of all data and store the data in result. 
        result = []
        a= data.tbody.findAll("tr")
        for i in a:
            ID = i.a["href"].split("/")[-1]
            name = i.find_all("td")[1].text
            date = i.find_all("td")[2].contents[0]
            link = i.a["href"]
            row = [ID,name,date,link]
            result.append(row)

        # Create a DataFrame
        df = pd.DataFrame(result,columns =column_name)

        # Store all data in to csv file

        df.to_csv('Taiyo_assing.csv', sep=',', index=False,header=True)
        # print the dataframe
        display(df)
        print("Web Scraping Successful!")

# %%
obj = Web_Scraping()
obj.Beautiful_Soup()
# Out:
#    Event ID                                         Event Name  \
# 0   01A6228      Clearance and Demolition Services Fortuna, CA
# 1   02A2151  IFB Janitorial and Custodial Grounds Maintenan...
# 2   03A3492  SB Minor B 03A3492 - Install Cured-In-Place Pi...
# 3   03A3503  SB Minor B 03A3503-Roadway Excavation, place H...
# 4   04A6476  IFB Multiple Provider Unsheltered Resident Enc...
# 5   04A6497  Operated Equipment Rental Services in Alameda,...
# 6   04A6498  Operated Equipment Rental Services in Alameda,...
# 7   04A6510  IFB Janitorial Services in Santa Clara County,...
# 8   04A6524  SB Minor B 04A6524 Install Midwest Guardrail S...
# 9   06A2855  IFB Trash and Recycle Pick-up, Hauling, and Di...
# 10  09A0882  IFB Concrete Sidewalk Repairs and Picnic Table...
# 11  10A2418  Inductive Loop Detector Repair and Replacement...
# 12  10A2440  Trash and Recycling Collection, Hauling, and D...
# 13  10A2445  SB Minor B 10A2445 Concrete Invert Paving and ...
# 14  32A0541  IFB Auctioneering Services to Dispose of Retir...
#
#                  End Date                                           link
# 0   08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/01A6228
# 1   08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/02A2151
# 2   08/19/22 - 2:15PM PDT  https://caleprocure.ca.gov/event/2660/03A3492
# 3   08/17/22 - 2:15PM PDT  https://caleprocure.ca.gov/event/2660/03A3503
# 4   08/18/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/04A6476
# 5   08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/04A6497
# 6   08/18/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/04A6498
# 7   08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/04A6510
# 8   08/23/22 - 2:15PM PDT  https://caleprocure.ca.gov/event/2660/04A6524
# 9   08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/06A2855
# 10  08/25/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/09A0882
# 11  08/16/22 - 2:30PM PDT  https://caleprocure.ca.gov/event/2660/10A2418
# 12  08/18/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/10A2440
# 13  08/12/22 - 2:15PM PDT  https://caleprocure.ca.gov/event/2660/10A2445
# 14  08/16/22 - 2:00PM PDT  https://caleprocure.ca.gov/event/2660/32A0541
# Web Scraping Successful!
